# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# # Introduction
#
# In this notebook, Data Science Tools and Ecosystem are summarized. We will explore various tools and technologies that are integral to the field of data science, providing a comprehensive overview of their functionalities and applications.

# %% [markdown]
# # Data Science Languages
#
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# # Data Science Libraries
#
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow

# %% [markdown]
# # Data Science Tools
#
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | Apache Zeppelin    |

# %% [markdown]
# ### Arithmetic Expression Examples
#
# Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This is a simple arithmetic expression to multiply then add integers
result = (3 * 4) + 5
result
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science
# - Identify commonly used libraries in Data Science
# - Recognize key Data Science tools and development environments
# - Demonstrate basic arithmetic operations in Python
# - Convert units of measurement (e.g., minutes to hours)

# %% [markdown]
# ## Author
#
# Satish K
